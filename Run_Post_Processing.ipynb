# %%
get_ipython().run_line_magic('matplotlib', 'inline')
import numpy as np
import matplotlib.pyplot as plt

import PostProcessing as PP
from nu_e_coll import nu_e_collisions as ve

folder = "../../{}-{:.4}-FullTestNew/{}-{:.4}-FullTestNew".format(300,1.28e-5,300,1.28e-5)
data = np.load(folder + "/mass_{}_mix_{:.4}.npz".format(300,1.28e-5), allow_pickle=True)
a_tot = data['scalefactors']
T_tot = data['temp']
e_tot = data['e']
f_tot = data['fe']

# %%
p_100 = e_tot[100][:]/a_tot[100]

print(len(p_100))

#change = ve.R12R24(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0])
#print(f_tot[100][671] + change)

# %%
A12_1 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],1,2,1)
print("A12_1 = " + str(A12_1))
A12_2 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],1,2,2)
print("A12_2 = " + str(A12_2))
A12_3 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],1,2,3)
print("A12_3 = " + str(A12_3))
A12_4 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],1,2,4)
print("A12_4 = " + str(A12_4))
A12_5 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],1,2,5)
print("A12_5 = " + str(A12_5))
A12_6 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],1,2,6)
print("A12_6 = " + str(A12_6))
A24_1 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,1)
print("A24_1 = " + str(A24_1))
A24_2 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,2)
print("A24_2 = " + str(A24_2))
A24_3 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,3)
print("A24_3 = " + str(A24_3))
A24_4 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,4)
print("A24_4 = " + str(A24_4))
A24_5 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,5)
print("A24_5 = " + str(A24_5))
A24_6 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,6)
print("A24_6 = " + str(A24_6))
A24_7 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,7)
print("A24_7 = " + str(A24_7))
A24_8 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,8)
print("A24_8 = " + str(A24_8))
A24_9 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,9)
print("A24_9 = " + str(A24_9))
A24_10 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,10)
print("A24_10 = " + str(A24_10))

# %%
A24_1 = ve.A(p_100[671],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,1)

UL, LL = ve.Alim(p_100[671],2,4,1)

print(UL,LL)

# %%
x_valuese, w_valuese = np.polynomial.legendre.leggauss(50)
E_arr = ((UL-LL)/2)*x_valuese + (UL+LL)/2 #could be E3 or E2 depending on if its R_1 or R_2
igrlp = 0
igrlm = 0
for i in range(len(E_arr)):
    Bp, Bm = ve.B(p_100[671],E_arr[i],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,1)
    print(Bp,Bm,i)
    igrlp = igrlp + w_valuese[i]*((UL-LL)/2)*Bp
    igrlm = igrlm + w_valuese[i]*((UL-LL)/2)*Bm

# %%
Bp, Bm = ve.B(p_100[671],E_arr[6],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,1)

Bp, Bm = ve.B(p_100[671],E_arr[7],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,1)

Bp, Bm = ve.B(p_100[671],E_arr[9],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,1)

Bp, Bm = ve.B(p_100[671],E_arr[13],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,1)

# %%
UL, LL = ve.Alim(p_100[671],2,4,1)
x_valuese, w_valuese = np.polynomial.legendre.leggauss(50)
E_arr = ((UL-LL)/2)*x_valuese + (UL+LL)/2 #could be E3 or E2 depending on if its R_1 or R_2

Earr6 = ve.B(p_100[671],E_arr[6],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,1)

Earr7 = ve.B(p_100[671],E_arr[7],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,1)

Earr9 = ve.B(p_100[671],E_arr[9],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,1)

Earr13 = ve.B(p_100[671],E_arr[13],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,1)

Earr14 = ve.B(p_100[671],E_arr[14],T_tot[100],f_tot[100][:],p_100[1]-p_100[0],2,4,1)

# %%
q2_arr = Earr6**2 - 0.511**2
q_arr = np.sqrt(q2_arr)

if ((0.51099999 <= Earr6[0]) & (Earr6[0] <= .511)):
    print("good")
    q2_arr[0] = 0
    q_arr[0] = 0
for i in range(len(q2_arr)):
    if abs(q2_arr[i]) < 1e-13:
        q_arr[i] = 0
    elif q2_arr[i]  < -1e-13:
        print("Error with q_array",q2_arr[i])
        q_arr[i] = 0

# %%
net_100 = np.zeros(len(p_100))

for i in range(len(p_100)-1):
    if p_100[i]>.2555:
        net_100[i] = ve.R12R24(p_100[i],T_tot[100],f_tot[100][:],p_100[1]-p_100[0])
        
plt.figure()
plt.semilogy(f_tot[100][:]+net_100)
plt.show()

# %%
#for i in range (len(e_tot[339])):
#    print(e_tot[339][i]) #yea boxsize is DEFINITELY NOT CONSTANT HERE, nu_e_coll assumes it is, grrrrr

bx = e_tot[340][1]-e_tot[340][0]
net = ve.driver(e_tot[340][:]/a_tot[340],T_tot[340],f_tot[340][:],bx*(1/a_tot[340]))
#A_model, n_model = ca.model_An(a_tot[339], T_tot[339], 1/(0.9 * a_tot[339] * T_tot[339]), e_tot[339][:], f_tot[339][:])

# %%
for i in range(len(net)):
    print(i,net[i])

# %%
plt.figure()
plt.semilogy(-net)
plt.show()

plt.figure()
plt.semilogy(net)
plt.show()

# %%
p_hold = e_tot[340][:]/a_tot[340]

net_hold = np.zeros(len(p_hold))

for i in range(len(p_hold)):
    if p_hold[i]>.2555:
        net_hold[i] = ve.R12R24(p_hold[i],T_tot[340],f_tot[340][:],p_hold[340][1]-p_hold[340][0])

# %%
plt.figure()
plt.semilogy(net_hold)
plt.show()

# %%
p_300 = e_tot[300][:]/a_tot[300]

net_300 = np.zeros(len(p_300))

for i in range(len(p_300)):
    if p_300[i]>.2555:
        net_300[i] = ve.R12R24(p_300[i],T_tot[300],f_tot[300][:],p_300[1]-p_300[300][0])
        
plt.figure()
plt.semilogy(net_300)
plt.show()

# %%
#for i in range(len(net_300)):
#    print(net_300[i])

plt.figure()
plt.semilogy(net_300)
plt.show()

plt.figure()
plt.semilogy(-net_300)
plt.show()

# %%
p_100 = e_tot[100][:]/a_tot[100]

print(ve.R12R24(p_100[22],T_tot[100],f_tot[100][:],p_100[1]-p_100[0]))

# %%
net_100 = np.zeros(len(p_100))

for i in range(len(p_100)-1):
    if p_100[i]>.2555:
        net_100[i] = ve.R12R24(p_100[i],T_tot[100],f_tot[100][:],p_100[1]-p_100[0])
        
plt.figure()
plt.semilogy(net_100)
plt.show()

plt.figure()
plt.semilogy(-net_100)
plt.show()

# %%
PP.pp(300,7e-5)

# %%
PP.pp(300,1.28e-5)

# %%
PP.inspect_graphs(300,7e-5)

# %%
PP.inspect_graphs(300,1.28e-5)

# %%
PP.make_graphs(300,7e-5)

# %%
PP.make_graphs(300,1.28e-5)

# %%
PP.make_movies(300,7e-5)

# %%
PP.make_movies(300,1.28e-5)

# %%
dilresults = np.load("/Users/hannahrasmussen/Work/Most_recent_code/300data/300data/300data_final.npz")
lifetime_array = dilresults['lifetime']
dil_array = dilresults['Dilution_Factor']
N_eff_array = dilresults['N_eff']

plt.figure(figsize=(8,6))
plt.semilogx(lifetime_array,dil_array,'o',color='k')
plt.xlabel("$\\tau(s)$",fontsize=16)
plt.ylabel("Dilution Factor",fontsize=16)
plt.tick_params(axis="x", labelsize=16)
plt.tick_params(axis="y", labelsize=16)
#plt.savefig("dilution.pdf")

plt.figure(figsize=(8,6))
plt.semilogx(lifetime_array,N_eff_array,'o',color='k')
plt.xlabel("$\\tau(s)$",fontsize=16)
plt.ylabel("$N_{\\rm eff}$",fontsize=16)
plt.tick_params(axis="x", labelsize=16)
plt.tick_params(axis="y", labelsize=16)
#plt.savefig("neff.pdf")

# %%
a_vals_135 = np.load("../../300-1.35e-05-FullTestNew/300-1.35e-05-FullTestNew/full-all-a_array.npy")
T_vals_135 = np.load("../../300-1.35e-05-FullTestNew/300-1.35e-05-FullTestNew/full-all-T_array.npy")

ylist_135 = [np.transpose(np.load("../../300-1.35e-05-FullTestNew/300-1.35e-05-FullTestNew/full-0-y.npy"))] 
elist_135 = [np.load("../../300-1.35e-05-FullTestNew/300-1.35e-05-FullTestNew/full-0-e.npy")]
length_135 = 42
for i in range(1,30): #this for loop is just to create ylist and elist and calculate length_135
    yhold = np.transpose(np.load("../../300-1.35e-05-FullTestNew/300-1.35e-05-FullTestNew/full-"+str(i)+"-y.npy")) #these are matrices
    ehold = np.load("../../300-1.35e-05-FullTestNew/300-1.35e-05-FullTestNew/full-"+str(i)+"-e.npy") #these are just arrays
    length_135 = length_135 + len(yhold)
    ylist_135.append(yhold)
    elist_135.append(ehold)

e_vals_135 = np.zeros((length_135,712))
f_vals_135 = np.zeros((length_135,len(e_vals_135[0,:]))) #extra 3 for dQ/da, T and t
t_vals_135 = np.zeros(len(a_vals_135))
s = 0
for i in range(30):
    ehold = elist_135[i]
    for j in range(len(ylist_135[i])):
        for k in range(len(ylist_135[i][j])-3): #this for loop doesn't account for dQ/da, T, and t
            f_vals_135[s+j][k] = ylist_135[i][j][k]
            e_vals_135[s+j][k] = ehold[k]
    s = s + len(ylist_135[i])
s = 0
for i in range(30):
    for j in range(len(ylist_135[i])): #this for loop only accounts for dQ/da, T, and t
            t_vals_135[s+j] = ylist_135[i][j][-1] #time
            #y_vals_135[s+j][-2] = ylist_135[i][j][-2] #temperature
            #y_vals_135[s+j][-3] = ylist_135[i][j][-3] #dQda
    s = s + len(ylist_135[i])

# %%
a_vals_800 = np.load("../../300-8e-05-FullTestNew/300-8e-05-FullTestNew/full-all-a_array.npy")
T_vals_800 = np.load("../../300-8e-05-FullTestNew/300-8e-05-FullTestNew/full-all-T_array.npy")

ylist_800 = [np.transpose(np.load("../../300-8e-05-FullTestNew/300-8e-05-FullTestNew/full-0-y.npy"))]
length_800 = 42
for i in range(1,20):
    yhold = np.transpose(np.load("../../300-8e-05-FullTestNew/300-8e-05-FullTestNew/full-"+str(i)+"-y.npy"))
    length_800 = length_800 + len(yhold)
    ylist_800.append(yhold)

e_vals_800 = np.zeros((length_800,595))
t_vals_800 = np.zeros(len(a_vals_800))
for i in range(length_800):
    for j in range(595):
        e_vals_800[i][j] = 0.5*j
f_vals_800 = np.zeros((length_800,len(e_vals_800[0,:]))) #extra 3 for dQ/da, T and t
s = 0
for i in range(20):
    for j in range(len(ylist_800[i])):
        for k in range(len(ylist_800[i][j])-3): #this for loop doesn't account for dQ/da, T, and t
            f_vals_800[s+j][k] = ylist_800[i][j][k]
    s = s + len(ylist_800[i])
s = 0
for i in range(20):
    for j in range(len(ylist_800[i])): #this for loop only accounts for dQ/da, T, and t
            t_vals_800[s+j] = ylist_800[i][j][-1] #time
            #y_vals_800[s+j][-2] = ylist_800[i][j][-2] #temperature
            #y_vals_800[s+j][-3] = ylist_800[i][j][-3] #dQda
    s = s + len(ylist_800[i])
